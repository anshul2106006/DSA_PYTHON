# %%
#list tuple
#list [] tuple(){set}{key:value}
list=[1,2,3,4,5,10,67,"hello",'A']
print(tuple)
print(type(tuple))

tuple=(1,2,3,5,'A',"python","java")
print(tuple)
print(type(tuple))
# Out:
# <class 'tuple'>
# <class 'type'>
# (1, 2, 3, 5, 'A', 'python', 'java')
# <class 'tuple'>

# %%
data=["hello","pyhton","java"]
print(data)
data.append("C++")
print(data)
data.insert(1,"php")
print(data)
data.remove("hello")
print(data)
# Out:
# ['hello', 'pyhton', 'java']
# ['hello', 'pyhton', 'java', 'C++']
# ['hello', 'php', 'pyhton', 'java', 'C++']
# ['php', 'pyhton', 'java', 'C++']

# %%
marks=[10,20,43,60,89,40]
marks.sort()
print(marks)
marks.reverse()
print(marks)
# Out:
# [10, 20, 40, 43, 60, 89]
# [89, 60, 43, 40, 20, 10]

# %%
#remove duplicates in list
num=[2,3,4,4,5,5,6,6,7,2]
rem=[]
for i in num:
  if i not in rem:
    rem.append(i)
print("Actual list:",num)
print("After removing: ",rem)
# Out:
# Actual list: [2, 3, 4, 4, 5, 5, 6, 6, 7, 2]
# After removing:  [2, 3, 4, 5, 6, 7]

# %%
#find second largest number
num=[12,45,78,56,34,89]
maximum=second_max=float('-inf')
for i in num:
  if i>maximum:
    second_max=maximum
    maximum=i
  elif i>second_max and i!=maximum:
    second_max=i
print("second largest number :",second_max)
# Out:
# second largest number : 78

# %%
#find all pairs sum is equal to target
num=[1,2,3,4,5,6,7,8]
target=10
for i in range(len(num)):
  for j in range(i+1,len(num)):
     if (num[i]+num[j]==target):
      rem.append((num[i],num[j]))
print("pair is",rem)
# Out:
# pair is [2, 3, 4, 5, 6, 7, (2, 8), (3, 7), (4, 6)]

# %%
#find ffrequency of each element
#count how many times each element appears in list
num=[1,2,2,3,4,4,5,5,5,5,]
dict={}
for i in num:
    dict[i]=dict.get(i,0)+1
    print(dict)

dict2={}
for i in num:
  if i in dict2:
    dict2[i]+=1
  else:
    dict2[i]=1
print(dict2)
# Out:
# {1: 1}
# {1: 1, 2: 1}
# {1: 1, 2: 2}
# {1: 1, 2: 2, 3: 1}
# {1: 1, 2: 2, 3: 1, 4: 1}
# {1: 1, 2: 2, 3: 1, 4: 2}
# {1: 1, 2: 2, 3: 1, 4: 2, 5: 1}
# {1: 1, 2: 2, 3: 1, 4: 2, 5: 2}
# {1: 1, 2: 2, 3: 1, 4: 2, 5: 3}
# {1: 1, 2: 2, 3: 1, 4: 2, 5: 4}
# {1: 1, 2: 2, 3: 1, 4: 2, 5: 4}
