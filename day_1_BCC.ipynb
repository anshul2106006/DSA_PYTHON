# %% [markdown]
# # Welcome to Colab!

# %%
print("Hello Students")
age=21
#More examples
name="Rahul"
salary=50000
temperature=36.5
# Out:
# Hello Students

# %%
#boolean (true/false)
#example
is_student = True

# %%
#This is string ,not number.
#convert to integer:
age =int("21")

# %%
#convert number to string
num=100
print(type(num))
text =str(num)
print(type(text))
# Out:
# <class 'int'>
# <class 'str'>

# %%
num1="10"
num2="20"
result=int(num1)+int(num2)
print(result)
# Out:
# 30

# %%
#taking input from user
age=input("enter your age")
ag1=int(input("enter your ag1:"))
print(age)
print(type(age))
# Out:
# enter your age20
# enter your ag1:21
# 20
# <class 'str'>

# %%
#find your current age
age_input = input("enter your DOB (YYYY): ")
current_age =2026-int(age_input)
print(current_age)
# Out:
# enter your DOB (YYYY): 2006
# 20

# %%
#find area of rectangle
length=float(input("enter length:"))
width=float(input("enter width:"))
area=length*width
print("area of rectangle =",area)
# Out:
# enter length:10
# enter width:20
# area of rectangle = 200.0

# %%
#find the conversion of celsius to fahrenheit
celsius=float(input("enter celsius:"))
fahrenheit=(celsius*9/5)+32
print("fahrenheit=",fahrenheit)
# Out:
# enter celsius:60
# fahrenheit= 140.0

# %%
#calculate simple interest
principal=float(input("enter principal:"))
rate=float(input("enter rate:"))
time=float(input("enter time:"))
simple_interest=(principal*rate*time)/100
print("simple interest=",simple_interest)
# Out:
# enter principal:50
# enter rate:60
# enter time:8
# simple interest= 240.0

# %%
#swap two numbers
num1=int(input("enter num1:"))
num2=int(input("enter num2:"))
num3=num1
num1=num2
num2=num3
print("num1=",num1)
print("num2=",num2)
# Out:
# enter num1:1
# enter num2:2
# num1= 2
# num2= 1

# %%
#find a square or cube of a number
a=int(input("enter a number:"))
b=a*a
c=a*a*a
print("square",b)
print("cube",c)
# Out:
# enter a number:52
# square 2704
# cube 140608

# %%
#convert minutes to hours
minutes=int(input("enter minutes:"))
hours=minutes/60
print("hours=",hours)
# Out:
# enter minutes:300
# hours= 5.0

# %%
#calculate average of three number
a=float(input("enter a number 1:"))
b=float(input("enter a number 2:"))
c=float(input("enter a number 3:"))
average=(a+b+c)/3
print("average=",average)
# Out:
# enter a number 1:52
# enter a number 2:84
# enter a number 3:84
# average= 73.33333333333333

# %%
#convert km to meters
km=float(input("enter km:"))
meters=km*1000
print("meters=",meters)
# Out:
# enter km:86
# meters= 86000.0

# %%
#convert rupees to dollar
rupees=float(input("enter rupees:"))
dollar=rupees/74
print("dollar=",dollar)
# Out:
# enter rupees:45
# dollar= 0.6081081081081081

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")

print("Hello", name + ", you are", age, "years old.")
# Out:
# Enter your name: ved
# Enter your age: 20
# Hello ved, you are 20 years old.

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))

perimeter = 2 * (length + width)

print("Perimeter of rectangle is:", perimeter)
# Out:
# Enter length: 10
# Enter width: 20
# Perimeter of rectangle is: 60.0

# %%
km = float(input("Enter distance in kilometers: "))

meters = km * 1000
centimeters = km * 100000

print("Meters:", meters)
print("Centimeters:", centimeters)
# Out:
# Enter distance in kilometers: 800
# Meters: 800000.0
# Centimeters: 80000000.0

# %%
p1 = float(input("Enter price of product 1: "))
p2 = float(input("Enter price of product 2: "))
p3 = float(input("Enter price of product 3: "))

total = p1 + p2 + p3

print("Total bill amount:", total)
# Out:
# Enter price of product 1: 86
# Enter price of product 2: 45
# Enter price of product 3: 63
# Total bill amount: 194.0

# %%
#check even odd number
number=int(input("enter any number"))
if number % 2==0:
  print("even number")
else:
  print("odd number")
# Out:
# enter any number28
# even number

# %%
number=int(input("enter any number"))
if number % 2==0:
  print("even number")
else:
  print("odd number")

if number & 1==0:
  print("even")

  if number % 2 !=0:
    print("odd")
# Out:
# enter any number25
# odd number

# %%
# find largest of three number
a=int(input("enter a number 1:"))
b=int(input("enter a number 2:"))
c=int(input("enter a number 3:"))

if a >= b and a >= c:
  print("a is largest")
elif b >= a and b >= c:
  print("b is largest")
else:
  print("c is largest")
# Out:
# enter a number 1:2
# enter a number 2:454
# enter a number 3:321
# b is largest
